# %%
import torch
import os
import sys
sys.path.append('../')
if 'DISPLAY' in os.environ:
    del os.environ['DISPLAY']

import numpy as np
import dill
import matplotlib.pyplot as plt
import joblib
from distributed import Client
from dask_jobqueue import SLURMCluster
import dask
from joblib import Parallel, delayed
import time
import random
import pandas as pd
import hnn_core
from hnn_core import simulate_dipole, Network, read_params, JoblibBackend, MPIBackend
import sbi.utils as utils
import datetime
import dask.bag as db
#from sbi_functions import HNNSimulator, run_simulator


cluster = SLURMCluster(cores = 100,
                       processes=100,
                       queue='compute',
                       memory="100GB",
                       walltime="24:00:00",
                       job_extra=['-A csd403', '--nodes=1']
)
#'--cpus-per-task=1'
client = Client(cluster)
client
# Out:
# <Client: 'tcp://198.202.103.227:35585' processes=0 threads=0, memory=0 B>

# %%
class HNNSimulator:
    def __init__(self, params_fname, prior_dict):
        if 'DISPLAY' in os.environ:
            del os.environ['DISPLAY']
            
        import hnn_core
        from hnn_core import simulate_dipole, Network, read_params, JoblibBackend, MPIBackend
        self.params = read_params(params_fname)
        #self.params['tstop'] = 100
        self.param_names = list(prior_dict.keys())

    def __call__(self, new_param_values):
        new_params = dict(zip(self.param_names, new_param_values.detach().cpu().numpy()))
        self.params.update(new_params)

        net = Network(self.params)
        with JoblibBackend(n_jobs=1):
            dpl = simulate_dipole(net, n_trials=1)

        summstats = dpl[0].data['agg']
        spike_times = net.cell_response.spike_times
        spike_gids = net.cell_response.spike_gids
        spike_types = net.cell_response.spike_types
        return summstats, spike_times, spike_gids, spike_types


#sbi_simulator, sbi_prior = prepare_for_sbi(hnn_simulator, prior)
#params = read_params(params_fname)
def run_simulator(theta, params_fname, prior_dict, sim_idx):
    hnn_simulator = HNNSimulator(params_fname,prior_dict)
    dpl, spike_times, spike_gids, spike_types = hnn_simulator(theta)
    return (dpl, spike_times, spike_gids, spike_types)

# %%
num_simulations = 10000
time_stamp = datetime.datetime.now().strftime("%m%d%Y_%H%M%S")

params_fname = '../../data/ERP/ERPYes.param'
save_suffix = 'ERP_Yes_t10000' + '_' + time_stamp
save_path = '../../data/ERP/prerun_simulations/' + save_suffix  + '/'

prior_dict = {'gbar_L2Pyr_L2Pyr_ampa':(0, 0.01),
'gbar_L2Pyr_L2Pyr_nmda':(0, 0.01), 
'gbar_L2Basket_L2Pyr_gabaa':(0, 0.1),
'gbar_L2Basket_L2Pyr_gabab':(0, 0.1),
'gbar_L2Pyr_L5Pyr':(0, 0.01),
'gbar_L2Basket_L5Pyr':(0, 0.1),
'gbar_L5Pyr_L5Pyr_ampa':(0, 0.01),
'gbar_L5Pyr_L5Pyr_nmda':(0, 0.01),
'gbar_L5Basket_L5Pyr_gabaa':(0, 0.1),
'gbar_L5Basket_L5Pyr_gabab':(0, 0.1),
'gbar_L2Pyr_L2Basket':(0, 0.01),
'gbar_L2Basket_L2Basket':(0, 0.1),
'gbar_L2Pyr_L5Basket':(0, 0.01),
'gbar_L5Pyr_L5Basket':(0, 0.01),
'gbar_L5Basket_L5Basket':(0, 0.1)}

param_low = [float(item[0]) for key, item in prior_dict.items()]
param_high = [float(item[1]) for key, item in prior_dict.items()]
prior = utils.BoxUniform(low=torch.tensor(param_low), high=torch.tensor(param_high))

theta_samples = prior.sample((num_simulations,))

def dill_save(save_object, save_prefix, save_suffix, save_path, extension='.pkl'):
    save_file = open(save_path + save_prefix + '_' + save_suffix + extension, 'wb')
    dill.dump(save_object, save_file)
    save_file.close()

os.mkdir(save_path)
os.mkdir(save_path + 'data/')
dill_save(params_fname, 'params_fname', save_suffix, save_path)
dill_save(prior, 'prior', save_suffix, save_path)
dill_save(prior_dict, 'prior_dict', save_suffix, save_path)

# %%
client.cluster.scale(1000)
def batch(seq, theta_samples, params_fname, prior_dict):
    res_list= []
    for sim_idx in seq:
        res = dask.delayed(run_simulator)(theta_samples[sim_idx,:], params_fname, prior_dict, sim_idx)
        res_list.append(res)
        
        

    final_res = dask.compute(*res_list)
    dpl_list = np.stack([final_res[idx][0] for idx in range(len(seq))])
    
    dpl_name = save_path + 'data/dpl_' + save_suffix + '_sim{}-{}'.format(seq[0],seq[-1]) + '.csv'
    param_name = save_path + 'data/theta_' + save_suffix + '_sim{}-{}'.format(seq[0],seq[-1]) + '.csv'

    np.savetxt(dpl_name, dpl_list, delimiter=',')
    np.savetxt(param_name, theta_samples[seq,:].detach().cpu().numpy(), delimiter=',')
    
    dill_save([final_res[idx][1] for idx in range(len(seq))], 'data/spike_times', save_suffix + '_sim{}-{}'.format(seq[0],seq[-1]), save_path)
    dill_save([final_res[idx][2] for idx in range(len(seq))], 'data/spike_gids', save_suffix + '_sim{}-{}'.format(seq[0],seq[-1]), save_path)
    dill_save([final_res[idx][3] for idx in range(len(seq))], 'data/spike_types', save_suffix + '_sim{}-{}'.format(seq[0],seq[-1]), save_path)

batches = []
step_size = 1000
for i in range(0, num_simulations, step_size):
    print(i)
    batch(list(range(i, i + step_size)),theta_samples, params_fname, prior_dict)
# Out:
# 0
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-1aa5f726-a490-444c-80b1-c87508c6a48f'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-27ff787d-dd81-4271-b0df-a87bfc32a4ea'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-1c2e39bc-e63c-4a93-9913-b801c33a3de4'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-07eb882f-ab98-4a0e-b065-a9dbfb47b5f2'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-11477a89-9e9b-4d60-8b0e-0e1b445a98c5'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-365cb7e2-c2e0-453e-99c5-6d6ed37eb05a'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-1fb4ebc6-3fd8-4e07-bad3-60772b83498b'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-0ea0091d-65c1-4bf2-b3a4-00ee2786ef1e'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-056767f8-2ea3-4dc3-9137-53690006e1ea'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-0990b8ae-3658-4c45-a18d-7624be07c6df'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-17efe9c7-a1da-4700-9180-46f81ba61ae0'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-020bda03-d7f7-4016-8160-a4345a2d6219'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-05cd0c01-fb72-4aee-ba95-c5888818eecb'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-14ad837b-cfbf-4467-b722-e010830c10e9'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-0b75be49-320c-4abd-93ab-fe0a2ab477df'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-06a8a786-cd97-4a50-bc53-13658b0656a1'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-011272b9-2004-492c-af35-48c6dfaa0e0e'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-04d06b5c-acd4-454a-a66f-60df3dce7dd3'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-026e137c-10b5-41ff-b037-dfccb6d37e11'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-30e9a60d-87ea-44a7-bc24-d8daf4d4bade'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-0635114b-fcc4-4dbc-9250-1237bc51ded9'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-46b52c78-9475-4741-9c8c-8782447af378'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-13c03677-398d-4816-b42d-0ad053dd0904'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-de72a249-526c-4ee4-bf77-9dbb68bf45a8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-0547296b-c015-4a62-b54e-a093e4226e43'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-f4561748-5ff9-49d4-99ca-871f93ee867b'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-a08c3916-febf-4d30-a138-233f087d742c'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-5e53778a-354b-403e-a50d-a205963c81ad'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-3645c498-8d04-4a1d-91f4-af834c501299'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-455483aa-724a-4df9-804d-553afec8ffb8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-253cfe68-1090-45c5-8129-b182f3b0f272'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-3fd92676-2fca-4c8b-a827-0fcb79bedbd5'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-e5383af3-5582-440e-8201-ddcd883774a8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-2ece6e5f-dd2d-4c46-9837-6376432f29be'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-e1ad32d9-6110-4287-ab67-87ae9738c9b0'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-2ece6e5f-dd2d-4c46-9837-6376432f29be'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-455483aa-724a-4df9-804d-553afec8ffb8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-e5383af3-5582-440e-8201-ddcd883774a8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-253cfe68-1090-45c5-8129-b182f3b0f272'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-2ece6e5f-dd2d-4c46-9837-6376432f29be'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-a08c3916-febf-4d30-a138-233f087d742c'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-88c922d5-3434-4329-907f-ad6a442381d8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-e1ad32d9-6110-4287-ab67-87ae9738c9b0'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-88c922d5-3434-4329-907f-ad6a442381d8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-5e53778a-354b-403e-a50d-a205963c81ad'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-f4561748-5ff9-49d4-99ca-871f93ee867b'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-3645c498-8d04-4a1d-91f4-af834c501299'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-3fd92676-2fca-4c8b-a827-0fcb79bedbd5'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-de72a249-526c-4ee4-bf77-9dbb68bf45a8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-88c922d5-3434-4329-907f-ad6a442381d8'
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/core.py", line 493, in handle_comm
#     result = handler(comm, **msg)
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in heartbeat_worker
#     ws._executing = {
#   File "/home/ntolley/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/scheduler.py", line 2197, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: 'run_simulator-88c922d5-3434-4329-907f-ad6a442381d8'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0516d2269eae> in <module>
#      25 for i in range(0, num_simulations, step_size):
#      26     print(i)
# ---> 27     batch(list(range(i, i + step_size)),theta_samples, params_fname, prior_dict)
#
# <ipython-input-5-0516d2269eae> in batch(seq, theta_samples, params_fname, prior_dict)
#       8
#       9
# ---> 10     final_res = dask.compute(*res_list)
#      11     dpl_list = np.stack([final_res[idx][0] for idx in range(len(seq))])
#      12
#
# ~/anaconda3/envs/sbi/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     559         postcomputes.append(x.__dask_postcompute__())
#     560
# --> 561     results = schedule(dsk, keys, **kwargs)
#     562     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     563
#
# ~/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2682                     should_rejoin = False
#    2683             try:
# -> 2684                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2685             finally:
#    2686                 for f in futures.values():
#
# ~/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1991             else:
#    1992                 local_worker = None
# -> 1993             return self.sync(
#    1994                 self._gather,
#    1995                 futures,
#
# ~/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     837             return future
#     838         else:
# --> 839             return sync(
#     840                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     841             )
#
# ~/anaconda3/envs/sbi/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     335     else:
#     336         while not e.is_set():
# --> 337             e.wait(10)
#     338     if error[0]:
#     339         typ, exc, tb = error[0]
#
# ~/anaconda3/envs/sbi/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
